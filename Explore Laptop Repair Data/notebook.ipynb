# %% [markdown]
# # Explore Laptop Repair Data

# %% [markdown]
# ## Task 1
#
# import pandas using the alias pd
#
# dataset url: https://raw.githubusercontent.com/cogxen/datasets/main/for-laboratory/exploring-data-with-python/laptops.csv

# %%
import pandas as pd

# %%
repair_url = 'https://raw.githubusercontent.com/cogxen/datasets/main/for-laboratory/exploring-data-with-python/laptops.csv'

# %% [markdown]
# ## Task 2
#
#  Import the dataset in laptops.csv and assign to the variable laptops.

# %%
laptops = pd.read_csv(repair_url)

# %% [markdown]
# ## Task 3
#
# Display the first five lines of the laptops DataFrame.

# %%
laptops.head()
# Out:
#             problem    brand  ... age  percent_problem_fixed
# 0     power/battery     dell  ...   7                  29.47
# 1           unknown   medion  ...   9                  48.08
# 2          multiple       hp  ...   6                  60.00
# 3     configuration       hp  ...   3                  67.74
# 4  operating system  samsung  ...   9                  59.72
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Task 4
#
# Display the data types of the laptops DataFrame columns.

# %%
laptops.dtypes
# Out:
# problem                   object
# brand                     object
# repair_status             object
# event_year                 int64
# age                        int64
# percent_problem_fixed    float64
# dtype: object

# %% [markdown]
# ## Task 5
#
# Let's take a look at the ages of laptops being brought in for repair. Use a series method to display the minimum, maximum, and other summary statistics for the age column. Do you notice anything interesting?

# %%
laptops['age'].describe()
# Out:
# count    815.000000
# mean       6.136196
# std        3.600758
# min        0.000000
# 25%        4.000000
# 50%        5.000000
# 75%        8.000000
# max       29.000000
# Name: age, dtype: float64

# %% [markdown]
# ## Task 6
#
# The other numeric column is event_year. Use a pandas method to determine the earliest and latest years in the dataset.

# %%
laptops['event_year'].agg(['min', 'max'])
# Out:
# min    2015
# max    2020
# Name: event_year, dtype: int64

# %% [markdown]
# ## Task 7
#
# Let's also take a look at event_year as a categorical column. Use a series method to output the number of laptops in the data for each event_year. What do you notice?

# %%
laptops['event_year'].value_counts()
# Out:
# event_year
# 2019    430
# 2018    194
# 2020    113
# 2017     76
# 2016      1
# 2015      1
# Name: count, dtype: int64

# %% [markdown]
# ## Task 8
#
#  Now, let's focus on the problems causing people to bring in laptops for repair. Use a series method to display the most common problems in the dataset. What do you notice?

# %%
laptops['problem'].value_counts()
# Out:
# problem
# unknown                       156
# power/battery                  95
# configuration                  93
# operating system               72
# integrated screen              68
# performance                    56
# boot                           44
# ports/slots/connectors         30
# internal storage               30
# integrated keyboard            28
# overheating                    28
# internal damage                22
# case/chassis                   20
# system board                   19
# virus/malware                  17
# other                          12
# multiple                       10
# integrated media component      7
# integrated optical drive        4
# integrated pointing device      4
# Name: count, dtype: int64

# %% [markdown]
# ## Task 9
#
#  Power and battery issues are pretty common, but what percentage of the data do they represent? Modify the method from the previous task to output percentages instead of counts.

# %%
laptops['problem'].value_counts(normalize=True) * 100
# Out:
# problem
# unknown                       19.141104
# power/battery                 11.656442
# configuration                 11.411043
# operating system               8.834356
# integrated screen              8.343558
# performance                    6.871166
# boot                           5.398773
# ports/slots/connectors         3.680982
# internal storage               3.680982
# integrated keyboard            3.435583
# overheating                    3.435583
# internal damage                2.699387
# case/chassis                   2.453988
# system board                   2.331288
# virus/malware                  2.085890
# other                          1.472393
# multiple                       1.226994
# integrated media component     0.858896
# integrated optical drive       0.490798
# integrated pointing device     0.490798
# Name: proportion, dtype: float64

# %% [markdown]
# ## Task 10
#
#  Lastly, let's look at how often laptops brought into these events are recorded as fixed. Use a pandas method to count the number of laptops in each category of repair_status.

# %%
laptops['repair_status'].value_counts()
# Out:
# repair_status
# fixed          391
# repairable     305
# end of life    107
# unknown         12
# Name: count, dtype: int64
